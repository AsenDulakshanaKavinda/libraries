# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
file_path = "../data/riceClassification.csv"
data_df = pd.read_csv(file_path)

# %%
data_df.head()
# Out:
#    id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0   1  4537        92.229316        64.012769      0.719916        4677
# 1   2  2872        74.691881        51.400454      0.725553        3015
# 2   3  3048        76.293164        52.043491      0.731211        3132
# 3   4  3073        77.033628        51.928487      0.738639        3157
# 4   5  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
data_df.dropna(inplace=True)
data_df.drop(['id'], axis=1,inplace=True)
print(data_df.shape)
# Out:
# (18185, 11)

# %%
data_df.head()
# Out:
#    Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  4537        92.229316        64.012769      0.719916        4677
# 1  2872        74.691881        51.400454      0.725553        3015
# 2  3048        76.293164        52.043491      0.731211        3132
# 3  3073        77.033628        51.928487      0.738639        3157
# 4  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
print(data_df["Class"].unique())
# Out:
# [1 0]

# %%
print(data_df["Class"].value_counts())
# Out:
# Class
# 1    9985
# 0    8200
# Name: count, dtype: int64

# %%
original_df  = data_df.copy()

# %%
for column in data_df.columns:
    data_df[column] = data_df[column]/data_df[column].abs().max()

data_df.head()
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  0.444368         0.503404         0.775435      0.744658    0.424873
# 1  0.281293         0.407681         0.622653      0.750489    0.273892
# 2  0.298531         0.416421         0.630442      0.756341    0.284520
# 3  0.300979         0.420463         0.629049      0.764024    0.286791
# 4  0.361704         0.464626         0.682901      0.775033    0.345385
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0       0.666610  0.741661   0.537029   0.844997      0.368316    1.0
# 1       0.530370  0.804230   0.409661   0.919215      0.371471    1.0
# 2       0.546380  0.856278   0.412994   0.959862      0.374747    1.0
# 3       0.548616  0.883772   0.414262   0.961818      0.379222    1.0
# 4       0.601418  0.867808   0.452954   0.966836      0.386007    1.0

# %%
X = np.array(data_df.iloc[:, :-1])
Y = np.array(data_df.iloc[:, -1])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(X_val.shape)
print(Y_val.shape)
# Out:
# (12729, 10)
# (2728, 10)
# (12729,)
# (2728,)
# (2728, 10)
# (2728,)

# %%
print(X.shape[1])
# Out:
# 10

# %%
BATCH_SIZE = 8
EPOCHS = 100
HIDDEN_NEURONS = 10
LR = 1e-3

# %%
class dataset(Dataset):
    def __init__(self, X, Y):
        self.X = torch.tensor(X, dtype=torch.float32).to(device)
        self.Y = torch.tensor(Y, dtype=torch.float32).to(device)

    def __len__(self):
        return len(self.X) # shape of the input
    
    def __getitem__(self, index):
        return self.X[index], self.Y[index]

# %%
training_data = dataset(X_train, Y_train)
validation_data = dataset(X_val, Y_val)
testing_data = dataset(X_test, Y_test)

# %%
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE, shuffle=True)
validation_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE, shuffle=True)

# %%
for x, y in train_dataloader:
    print(x)
    print("+++++")
    print(y)
    break
# Out:
# tensor([[0.7573, 0.7696, 0.8642, 0.8922, 0.7255, 0.8702, 0.8901, 0.6937, 0.8631,
#          0.5053],
#         [0.9888, 0.8603, 1.0000, 0.8812, 0.9683, 0.9944, 0.6742, 0.8179, 0.8106,
#          0.4881],
#         [0.8283, 0.8354, 0.8686, 0.9138, 0.7938, 0.9101, 0.7102, 0.7343, 0.8424,
#          0.5457],
#         [0.8101, 0.8453, 0.8290, 0.9279, 0.7691, 0.9000, 0.7261, 0.7372, 0.8174,
#          0.5785],
#         [0.5863, 0.8404, 0.6121, 0.9771, 0.5554, 0.7657, 0.9248, 0.6624, 0.7328,
#          0.7791],
#         [0.6082, 0.7153, 0.7447, 0.9135, 0.5747, 0.7799, 0.8369, 0.6266, 0.8496,
#          0.5450],
#         [0.5763, 0.8250, 0.6195, 0.9734, 0.5549, 0.7591, 0.6491, 0.6775, 0.6886,
#          0.7556],
#         [0.6348, 0.8292, 0.6690, 0.9636, 0.6045, 0.7967, 0.6352, 0.6761, 0.7615,
#          0.7032]])
# +++++
# tensor([0., 0., 0., 0., 1., 0., 1., 1.])

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()

        self.input_layer = nn.Linear(X.shape[1], HIDDEN_NEURONS)
        self.linear = nn.Linear(HIDDEN_NEURONS, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.input_layer(x)
        x = self.linear(x)
        x = self.sigmoid(x)
        return x

model = MyModel().to(device)

# %%
summary(model, (X.shape[1], ))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Linear: 1-1                            [-1, 10]                  110
# ├─Linear: 1-2                            [-1, 1]                   11
# ├─Sigmoid: 1-3                           [-1, 1]                   --
# ==========================================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Linear: 1-1                            [-1, 10]                  110
# ├─Linear: 1-2                            [-1, 1]                   11
# ├─Sigmoid: 1-3                           [-1, 1]                   --
# ==========================================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %%
criterion = nn.BCELoss()
optimizer = Adam(model.parameters(), lr=LR)

# %%
total_loss_train_plot = []
total_loss_validation_plot = []
total_acc_train_plot = []
total_acc_validation_plot = []

for epoch in range(EPOCHS):
    total_acc_train = 0
    total_loss_train = 0
    total_acc_val = 0
    total_loss_val = 0
    ## Training and Validation
    for data in train_dataloader:

        inputs, labels = data

        prediction = model(inputs).squeeze(1)

        batch_loss = criterion(prediction, labels)

        total_loss_train += batch_loss.item()

        acc = ((prediction).round() == labels).sum().item()

        total_acc_train += acc

        batch_loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    ## Validation
    with torch.no_grad():
        for data in validation_dataloader:
            inputs, labels = data

            prediction = model(inputs).squeeze(1)

            batch_loss = criterion(prediction, labels)

            total_loss_val += batch_loss.item()

            acc = ((prediction).round() == labels).sum().item()

            total_acc_val += acc

    total_loss_train_plot.append(round(total_loss_train/1000, 4))
    total_loss_validation_plot.append(round(total_loss_val/1000, 4))
    total_acc_train_plot.append(round(total_acc_train/(training_data.__len__())*100, 4))
    total_acc_validation_plot.append(round(total_acc_val/(validation_data.__len__())*100, 4))
    total_acc_validation_plot.append(round(total_acc_val / len(validation_dataloader.dataset) * 100, 4))


    print(f'''Epoch no. {epoch + 1} Train Loss: {total_loss_train/1000:.4f} 
          Train Accuracy: {(total_acc_train/(training_data.__len__())*100):.4f} 
          Validation Loss: {total_loss_val/1000:.4f} 
          Validation Accuracy: {(total_acc_val / len(validation_dataloader.dataset) * 100):.4f}''')
    print("="*50)
# Out:
# Epoch no. 1 Train Loss: 0.5305
#           Train Accuracy: 95.7734
#           Validation Loss: 0.1742
#           Validation Accuracy: 98.1381
# ==================================================
# Epoch no. 2 Train Loss: 0.1189
#           Train Accuracy: 98.5466
#           Validation Loss: 0.0878
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 3 Train Loss: 0.0805
#           Train Accuracy: 98.6488
#           Validation Loss: 0.0716
#           Validation Accuracy: 98.6802
# ==================================================
# Epoch no. 4 Train Loss: 0.0706
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0664
#           Validation Accuracy: 98.7430
# ==================================================
# Epoch no. 5 Train Loss: 0.0687
#           Train Accuracy: 98.6880
#           Validation Loss: 0.0690
#           Validation Accuracy: 98.6095
# ==================================================
# Epoch no. 6 Train Loss: 0.0658
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0690
#           Validation Accuracy: 98.5623
# ==================================================
# Epoch no. 7 Train Loss: 0.0675
#           Train Accuracy: 98.6173
#           Validation Loss: 0.0692
#           Validation Accuracy: 98.5623
# ==================================================
# Epoch no. 8 Train Loss: 0.0655
#           Train Accuracy: 98.6016
#           Validation Loss: 0.0662
#           Validation Accuracy: 98.6252
# ==================================================
# Epoch no. 9 Train Loss: 0.0649
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0638
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 10 Train Loss: 0.0654
#           Train Accuracy: 98.6173
#           Validation Loss: 0.0710
#           Validation Accuracy: 98.5388
# ==================================================
# Epoch no. 11 Train Loss: 0.0654
#           Train Accuracy: 98.6173
#           Validation Loss: 0.0627
#           Validation Accuracy: 98.6645
# ==================================================
# Epoch no. 12 Train Loss: 0.0655
#           Train Accuracy: 98.6645
#           Validation Loss: 0.0651
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 13 Train Loss: 0.0653
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0624
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 14 Train Loss: 0.0647
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0678
#           Validation Accuracy: 98.6173
# ==================================================
# Epoch no. 15 Train Loss: 0.0659
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0623
#           Validation Accuracy: 98.7587
# ==================================================
# Epoch no. 16 Train Loss: 0.0660
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0623
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 17 Train Loss: 0.0652
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0807
#           Validation Accuracy: 98.1774
# ==================================================
# Epoch no. 18 Train Loss: 0.0657
#           Train Accuracy: 98.5938
#           Validation Loss: 0.0652
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 19 Train Loss: 0.0653
#           Train Accuracy: 98.5938
#           Validation Loss: 0.0626
#           Validation Accuracy: 98.6645
# ==================================================
# Epoch no. 20 Train Loss: 0.0646
#           Train Accuracy: 98.6645
#           Validation Loss: 0.0749
#           Validation Accuracy: 98.4366
# ==================================================
# Epoch no. 21 Train Loss: 0.0668
#           Train Accuracy: 98.6095
#           Validation Loss: 0.0621
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 22 Train Loss: 0.0651
#           Train Accuracy: 98.6645
#           Validation Loss: 0.0624
#           Validation Accuracy: 98.6723
# ==================================================
# Epoch no. 23 Train Loss: 0.0654
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0640
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 24 Train Loss: 0.0651
#           Train Accuracy: 98.6488
#           Validation Loss: 0.0629
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 25 Train Loss: 0.0649
#           Train Accuracy: 98.6959
#           Validation Loss: 0.0657
#           Validation Accuracy: 98.6409
# ==================================================
# Epoch no. 26 Train Loss: 0.0640
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0652
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 27 Train Loss: 0.0651
#           Train Accuracy: 98.6173
#           Validation Loss: 0.0621
#           Validation Accuracy: 98.6802
# ==================================================
# Epoch no. 28 Train Loss: 0.0653
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0626
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 29 Train Loss: 0.0650
#           Train Accuracy: 98.6173
#           Validation Loss: 0.0620
#           Validation Accuracy: 98.7037
# ==================================================
# Epoch no. 30 Train Loss: 0.0648
#           Train Accuracy: 98.6645
#           Validation Loss: 0.0651
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 31 Train Loss: 0.0640
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0684
#           Validation Accuracy: 98.5859
# ==================================================
# Epoch no. 32 Train Loss: 0.0630
#           Train Accuracy: 98.6330
#           Validation Loss: 0.0666
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 33 Train Loss: 0.0654
#           Train Accuracy: 98.6880
#           Validation Loss: 0.0647
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 34 Train Loss: 0.0644
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0629
#           Validation Accuracy: 98.7037
# ==================================================
# Epoch no. 35 Train Loss: 0.0642
#           Train Accuracy: 98.7037
#           Validation Loss: 0.0655
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 36 Train Loss: 0.0648
#           Train Accuracy: 98.6016
#           Validation Loss: 0.0627
#           Validation Accuracy: 98.7037
# ==================================================
# Epoch no. 37 Train Loss: 0.0648
#           Train Accuracy: 98.6252
#           Validation Loss: 0.0618
#           Validation Accuracy: 98.7823
# ==================================================
# Epoch no. 38 Train Loss: 0.0655
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0621
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 39 Train Loss: 0.0638
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0638
#           Validation Accuracy: 98.6409
# ==================================================
# Epoch no. 40 Train Loss: 0.0641
#           Train Accuracy: 98.6173
#           Validation Loss: 0.0619
#           Validation Accuracy: 98.6959
# ==================================================
# Epoch no. 41 Train Loss: 0.0640
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0640
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 42 Train Loss: 0.0640
#           Train Accuracy: 98.7430
#           Validation Loss: 0.0619
#           Validation Accuracy: 98.7587
# ==================================================
# Epoch no. 43 Train Loss: 0.0646
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0616
#           Validation Accuracy: 98.7430
# ==================================================
# Epoch no. 44 Train Loss: 0.0640
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0630
#           Validation Accuracy: 98.6252
# ==================================================
# Epoch no. 45 Train Loss: 0.0642
#           Train Accuracy: 98.7587
#           Validation Loss: 0.0683
#           Validation Accuracy: 98.6016
# ==================================================
# Epoch no. 46 Train Loss: 0.0641
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0633
#           Validation Accuracy: 98.7037
# ==================================================
# Epoch no. 47 Train Loss: 0.0645
#           Train Accuracy: 98.7037
#           Validation Loss: 0.0692
#           Validation Accuracy: 98.5623
# ==================================================
# Epoch no. 48 Train Loss: 0.0648
#           Train Accuracy: 98.7273
#           Validation Loss: 0.0628
#           Validation Accuracy: 98.7116
# ==================================================
# Epoch no. 49 Train Loss: 0.0660
#           Train Accuracy: 98.5623
#           Validation Loss: 0.0618
#           Validation Accuracy: 98.6802
# ==================================================
# Epoch no. 50 Train Loss: 0.0633
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0616
#           Validation Accuracy: 98.7195
# ==================================================
# Epoch no. 51 Train Loss: 0.0646
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0621
#           Validation Accuracy: 98.6802
# ==================================================
# Epoch no. 52 Train Loss: 0.0640
#           Train Accuracy: 98.7037
#           Validation Loss: 0.0651
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 53 Train Loss: 0.0637
#           Train Accuracy: 98.7037
#           Validation Loss: 0.0667
#           Validation Accuracy: 98.6173
# ==================================================
# Epoch no. 54 Train Loss: 0.0642
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0653
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 55 Train Loss: 0.0633
#           Train Accuracy: 98.7587
#           Validation Loss: 0.0614
#           Validation Accuracy: 98.7980
# ==================================================
# Epoch no. 56 Train Loss: 0.0634
#           Train Accuracy: 98.7116
#           Validation Loss: 0.0668
#           Validation Accuracy: 98.6173
# ==================================================
# Epoch no. 57 Train Loss: 0.0643
#           Train Accuracy: 98.5938
#           Validation Loss: 0.0616
#           Validation Accuracy: 98.6880
# ==================================================
# Epoch no. 58 Train Loss: 0.0646
#           Train Accuracy: 98.5938
#           Validation Loss: 0.0614
#           Validation Accuracy: 98.7352
# ==================================================
# Epoch no. 59 Train Loss: 0.0641
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0649
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 60 Train Loss: 0.0639
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0627
#           Validation Accuracy: 98.7116
# ==================================================
# Epoch no. 61 Train Loss: 0.0630
#           Train Accuracy: 98.7273
#           Validation Loss: 0.0654
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 62 Train Loss: 0.0644
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0632
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 63 Train Loss: 0.0643
#           Train Accuracy: 98.6488
#           Validation Loss: 0.0613
#           Validation Accuracy: 98.7902
# ==================================================
# Epoch no. 64 Train Loss: 0.0631
#           Train Accuracy: 98.6330
#           Validation Loss: 0.0612
#           Validation Accuracy: 98.7823
# ==================================================
# Epoch no. 65 Train Loss: 0.0637
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0612
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 66 Train Loss: 0.0637
#           Train Accuracy: 98.7587
#           Validation Loss: 0.0716
#           Validation Accuracy: 98.4681
# ==================================================
# Epoch no. 67 Train Loss: 0.0642
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0629
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 68 Train Loss: 0.0637
#           Train Accuracy: 98.6880
#           Validation Loss: 0.0636
#           Validation Accuracy: 98.6723
# ==================================================
# Epoch no. 69 Train Loss: 0.0636
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0628
#           Validation Accuracy: 98.7116
# ==================================================
# Epoch no. 70 Train Loss: 0.0650
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0615
#           Validation Accuracy: 98.7430
# ==================================================
# Epoch no. 71 Train Loss: 0.0638
#           Train Accuracy: 98.7823
#           Validation Loss: 0.0635
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 72 Train Loss: 0.0640
#           Train Accuracy: 98.6488
#           Validation Loss: 0.0628
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 73 Train Loss: 0.0635
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0643
#           Validation Accuracy: 98.6330
# ==================================================
# Epoch no. 74 Train Loss: 0.0632
#           Train Accuracy: 98.7273
#           Validation Loss: 0.0629
#           Validation Accuracy: 98.6723
# ==================================================
# Epoch no. 75 Train Loss: 0.0643
#           Train Accuracy: 98.6252
#           Validation Loss: 0.0612
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 76 Train Loss: 0.0644
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0616
#           Validation Accuracy: 98.7037
# ==================================================
# Epoch no. 77 Train Loss: 0.0639
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0612
#           Validation Accuracy: 98.7430
# ==================================================
# Epoch no. 78 Train Loss: 0.0638
#           Train Accuracy: 98.6959
#           Validation Loss: 0.0612
#           Validation Accuracy: 98.7980
# ==================================================
# Epoch no. 79 Train Loss: 0.0637
#           Train Accuracy: 98.6802
#           Validation Loss: 0.0633
#           Validation Accuracy: 98.6880
# ==================================================
# Epoch no. 80 Train Loss: 0.0625
#           Train Accuracy: 98.7509
#           Validation Loss: 0.0726
#           Validation Accuracy: 98.4602
# ==================================================
# Epoch no. 81 Train Loss: 0.0641
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0632
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 82 Train Loss: 0.0634
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0625
#           Validation Accuracy: 98.7116
# ==================================================
# Epoch no. 83 Train Loss: 0.0635
#           Train Accuracy: 98.7509
#           Validation Loss: 0.0609
#           Validation Accuracy: 98.7823
# ==================================================
# Epoch no. 84 Train Loss: 0.0639
#           Train Accuracy: 98.7195
#           Validation Loss: 0.0637
#           Validation Accuracy: 98.6409
# ==================================================
# Epoch no. 85 Train Loss: 0.0636
#           Train Accuracy: 98.7430
#           Validation Loss: 0.0613
#           Validation Accuracy: 98.6959
# ==================================================
# Epoch no. 86 Train Loss: 0.0628
#           Train Accuracy: 98.7509
#           Validation Loss: 0.0712
#           Validation Accuracy: 98.5859
# ==================================================
# Epoch no. 87 Train Loss: 0.0636
#           Train Accuracy: 98.6959
#           Validation Loss: 0.0669
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 88 Train Loss: 0.0638
#           Train Accuracy: 98.6723
#           Validation Loss: 0.0618
#           Validation Accuracy: 98.7195
# ==================================================
# Epoch no. 89 Train Loss: 0.0635
#           Train Accuracy: 98.7037
#           Validation Loss: 0.0632
#           Validation Accuracy: 98.7116
# ==================================================
# Epoch no. 90 Train Loss: 0.0633
#           Train Accuracy: 98.7195
#           Validation Loss: 0.0670
#           Validation Accuracy: 98.6566
# ==================================================
# Epoch no. 91 Train Loss: 0.0629
#           Train Accuracy: 98.7273
#           Validation Loss: 0.0609
#           Validation Accuracy: 98.7509
# ==================================================
# Epoch no. 92 Train Loss: 0.0630
#           Train Accuracy: 98.6959
#           Validation Loss: 0.0665
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 93 Train Loss: 0.0635
#           Train Accuracy: 98.6566
#           Validation Loss: 0.0613
#           Validation Accuracy: 98.7745
# ==================================================
# Epoch no. 94 Train Loss: 0.0633
#           Train Accuracy: 98.7587
#           Validation Loss: 0.0677
#           Validation Accuracy: 98.5859
# ==================================================
# Epoch no. 95 Train Loss: 0.0637
#           Train Accuracy: 98.6645
#           Validation Loss: 0.0610
#           Validation Accuracy: 98.7902
# ==================================================
# Epoch no. 96 Train Loss: 0.0633
#           Train Accuracy: 98.7509
#           Validation Loss: 0.0609
#           Validation Accuracy: 98.7745
# ==================================================
# Epoch no. 97 Train Loss: 0.0644
#           Train Accuracy: 98.6959
#           Validation Loss: 0.0618
#           Validation Accuracy: 98.7195
# ==================================================
# Epoch no. 98 Train Loss: 0.0631
#           Train Accuracy: 98.6330
#           Validation Loss: 0.0663
#           Validation Accuracy: 98.6488
# ==================================================
# Epoch no. 99 Train Loss: 0.0632
#           Train Accuracy: 98.6409
#           Validation Loss: 0.0609
#           Validation Accuracy: 98.7195
# ==================================================
# Epoch no. 100 Train Loss: 0.0628
#           Train Accuracy: 98.7430
#           Validation Loss: 0.0687
#           Validation Accuracy: 98.6252
# ==================================================

# %%
with torch.no_grad():
  total_loss_test = 0
  total_acc_test = 0
  for data in test_dataloader:
    inputs, labels = data

    prediction = model(inputs).squeeze(1)

    batch_loss_test = criterion((prediction), labels)
    total_loss_test += batch_loss_test.item()
    acc = ((prediction).round() == labels).sum().item()
    total_acc_test += acc

test_accuracy = round((total_acc_test / len(test_dataloader.dataset)) * 100, 2)
print(f"Accuracy Score is: {test_accuracy}%")
# Out:
# Accuracy Score is: 98.63%

# %%
print(total_loss_train_plot)
print(total_loss_validation_plot)
print(total_acc_train_plot)
print(total_acc_validation_plot)
# Out:
# [0.5305, 0.1189, 0.0805, 0.0706, 0.0687, 0.0658, 0.0675, 0.0655, 0.0649, 0.0654, 0.0654, 0.0655, 0.0653, 0.0647, 0.0659, 0.066, 0.0652, 0.0657, 0.0653, 0.0646, 0.0668, 0.0651, 0.0654, 0.0651, 0.0649, 0.064, 0.0651, 0.0653, 0.065, 0.0648, 0.064, 0.063, 0.0654, 0.0644, 0.0642, 0.0648, 0.0648, 0.0655, 0.0638, 0.0641, 0.064, 0.064, 0.0646, 0.064, 0.0642, 0.0641, 0.0645, 0.0648, 0.066, 0.0633, 0.0646, 0.064, 0.0637, 0.0642, 0.0633, 0.0634, 0.0643, 0.0646, 0.0641, 0.0639, 0.063, 0.0644, 0.0643, 0.0631, 0.0637, 0.0637, 0.0642, 0.0637, 0.0636, 0.065, 0.0638, 0.064, 0.0635, 0.0632, 0.0643, 0.0644, 0.0639, 0.0638, 0.0637, 0.0625, 0.0641, 0.0634, 0.0635, 0.0639, 0.0636, 0.0628, 0.0636, 0.0638, 0.0635, 0.0633, 0.0629, 0.063, 0.0635, 0.0633, 0.0637, 0.0633, 0.0644, 0.0631, 0.0632, 0.0628]
# [0.1742, 0.0878, 0.0716, 0.0664, 0.069, 0.069, 0.0692, 0.0662, 0.0638, 0.071, 0.0627, 0.0651, 0.0624, 0.0678, 0.0623, 0.0623, 0.0807, 0.0652, 0.0626, 0.0749, 0.0621, 0.0624, 0.064, 0.0629, 0.0657, 0.0652, 0.0621, 0.0626, 0.062, 0.0651, 0.0684, 0.0666, 0.0647, 0.0629, 0.0655, 0.0627, 0.0618, 0.0621, 0.0638, 0.0619, 0.064, 0.0619, 0.0616, 0.063, 0.0683, 0.0633, 0.0692, 0.0628, 0.0618, 0.0616, 0.0621, 0.0651, 0.0667, 0.0653, 0.0614, 0.0668, 0.0616, 0.0614, 0.0649, 0.0627, 0.0654, 0.0632, 0.0613, 0.0612, 0.0612, 0.0716, 0.0629, 0.0636, 0.0628, 0.0615, 0.0635, 0.0628, 0.0643, 0.0629, 0.0612, 0.0616, 0.0612, 0.0612, 0.0633, 0.0726, 0.0632, 0.0625, 0.0609, 0.0637, 0.0613, 0.0712, 0.0669, 0.0618, 0.0632, 0.067, 0.0609, 0.0665, 0.0613, 0.0677, 0.061, 0.0609, 0.0618, 0.0663, 0.0609, 0.0687]
# [95.7734, 98.5466, 98.6488, 98.6409, 98.688, 98.6409, 98.6173, 98.6016, 98.6409, 98.6173, 98.6173, 98.6645, 98.6566, 98.6409, 98.6566, 98.6723, 98.6566, 98.5938, 98.5938, 98.6645, 98.6095, 98.6645, 98.6723, 98.6488, 98.6959, 98.6802, 98.6173, 98.6409, 98.6173, 98.6645, 98.6409, 98.633, 98.688, 98.6723, 98.7037, 98.6016, 98.6252, 98.6566, 98.6566, 98.6173, 98.6566, 98.743, 98.6723, 98.6802, 98.7587, 98.6566, 98.7037, 98.7273, 98.5623, 98.6566, 98.6566, 98.7037, 98.7037, 98.6723, 98.7587, 98.7116, 98.5938, 98.5938, 98.6566, 98.6802, 98.7273, 98.6409, 98.6488, 98.633, 98.6802, 98.7587, 98.6802, 98.688, 98.6409, 98.6566, 98.7823, 98.6488, 98.6802, 98.7273, 98.6252, 98.6802, 98.6723, 98.6959, 98.6802, 98.7509, 98.6566, 98.6409, 98.7509, 98.7195, 98.743, 98.7509, 98.6959, 98.6723, 98.7037, 98.7195, 98.7273, 98.6959, 98.6566, 98.7587, 98.6645, 98.7509, 98.6959, 98.633, 98.6409, 98.743]
# [457.9179, 98.1381, 460.3006, 98.6488, 460.4472, 98.6802, 460.7405, 98.743, 460.1173, 98.6095, 459.8974, 98.5623, 459.8974, 98.5623, 460.1906, 98.6252, 460.3006, 98.6488, 459.7874, 98.5388, 460.3739, 98.6645, 460.2273, 98.633, 460.7771, 98.7509, 460.154, 98.6173, 460.8138, 98.7587, 460.7771, 98.7509, 458.1012, 98.1774, 460.2273, 98.633, 460.3739, 98.6645, 459.3109, 98.4366, 460.7771, 98.7509, 460.4106, 98.6723, 460.3006, 98.6488, 460.2273, 98.633, 460.2639, 98.6409, 460.3372, 98.6566, 460.4472, 98.6802, 460.3006, 98.6488, 460.5572, 98.7037, 460.3372, 98.6566, 460.0073, 98.5859, 460.2273, 98.633, 460.2273, 98.633, 460.5572, 98.7037, 460.3006, 98.6488, 460.5572, 98.7037, 460.9238, 98.7823, 460.7771, 98.7509, 460.2639, 98.6409, 460.5205, 98.6959, 460.2273, 98.633, 460.8138, 98.7587, 460.7405, 98.743, 460.1906, 98.6252, 460.0806, 98.6016, 460.5572, 98.7037, 459.8974, 98.5623, 460.5938, 98.7116, 460.4472, 98.6802, 460.6305, 98.7195, 460.4472, 98.6802, 460.3372, 98.6566, 460.154, 98.6173, 460.3372, 98.6566, 460.9971, 98.798, 460.154, 98.6173, 460.4839, 98.688, 460.7038, 98.7352, 460.3372, 98.6566, 460.5938, 98.7116, 460.3006, 98.6488, 460.3372, 98.6566, 460.9604, 98.7902, 460.9238, 98.7823, 460.7771, 98.7509, 459.4575, 98.4681, 460.2273, 98.633, 460.4106, 98.6723, 460.5938, 98.7116, 460.7405, 98.743, 460.3006, 98.6488, 460.3006, 98.6488, 460.2273, 98.633, 460.4106, 98.6723, 460.7771, 98.7509, 460.5572, 98.7037, 460.7405, 98.743, 460.9971, 98.798, 460.4839, 98.688, 459.4208, 98.4602, 460.3372, 98.6566, 460.5938, 98.7116, 460.9238, 98.7823, 460.2639, 98.6409, 460.5205, 98.6959, 460.0073, 98.5859, 460.3372, 98.6566, 460.6305, 98.7195, 460.5938, 98.7116, 460.3372, 98.6566, 460.7771, 98.7509, 460.3006, 98.6488, 460.8871, 98.7745, 460.0073, 98.5859, 460.9604, 98.7902, 460.8871, 98.7745, 460.6305, 98.7195, 460.3006, 98.6488, 460.6305, 98.7195, 460.1906, 98.6252]

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

axs[0].plot(total_loss_train_plot, label='Training Loss')
axs[0].plot(total_loss_validation_plot, label='Validation Loss')
axs[0].set_title('Training and Validation Loss over Epochs')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].set_ylim([0, 0.6])
axs[0].legend()

axs[1].plot(total_acc_train_plot, label='Training Accuracy')
axs[1].plot(total_acc_validation_plot, label='Validation Accuracy')
axs[1].set_title('Training and Validation Accuracy over Epochs')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].set_ylim([95, 100])
axs[1].legend()

plt.tight_layout()

plt.show()

# %%
area = float(input("Area: "))/original_df['Area'].abs().max()
MajorAxisLength = float(input("Major Axis Length: "))/original_df['MajorAxisLength'].abs().max()
MinorAxisLength = float(input("Minor Axis Length: "))/original_df['MinorAxisLength'].abs().max()
Eccentricity = float(input("Eccentricity: "))/original_df['Eccentricity'].abs().max()
ConvexArea = float(input("Convex Area: "))/original_df['ConvexArea'].abs().max()
EquivDiameter = float(input("EquivDiameter: "))/original_df['EquivDiameter'].abs().max()
Extent = float(input("Extent: "))/original_df['Extent'].abs().max()
Perimeter = float(input("Perimeter: "))/original_df['Perimeter'].abs().max()
Roundness = float(input("Roundness: "))/original_df['Roundness'].abs().max()
AspectRation = float(input("AspectRation: "))/original_df['AspectRation'].abs().max()

my_inputs = [area, MajorAxisLength, MinorAxisLength, Eccentricity, ConvexArea, EquivDiameter, Extent, Perimeter, Roundness, AspectRation]

print("="*20)
model_inputs = torch.Tensor(my_inputs).to(device)
prediction = (model(model_inputs))
print(prediction)
print("Class is: ", round(prediction.item()))
